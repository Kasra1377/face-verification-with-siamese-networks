# %%
import os

# %%
# definine a shape for input data into the model
IMG_SHAPE = (62, 47, 1)

# specify the batch_size and number of epochs and learning rate
# as a parameter for out network
BATCH_SIZE = 4
EPOCHS = 50
LEARNING_RATE = 1e-3

# %%
# define a base path for project outputs
BASE_OUTPUT = "output"

# use join method to save siamese model and its plot into 
# output subdirectory
MODEL_PATH = os.path.sep.join([BASE_OUTPUT, "siamese-model"])
PLOT_PATH = os.path.sep.join([BASE_OUTPUT, "plot.png"])
